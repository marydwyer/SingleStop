# %%
import pandas as pd
import numpy as np

# %%
client = pd.read_csv("CoopersUnion_eval_clientinfo_201712291322.csv")
studies = pd.read_csv("coopersunion_eval_studies_data_201712281747.csv")
# Out:
# C:\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
combined = studies.merge(client, left_on="hhid", right_on="household_id", how="left")
combined.head()
# Out:
#   hhid             action_type    bc_id activity_id  benefit_id  \
# 0    3                 created      NaN         NaN         NaN
# 1    7  application_submission  149,028      89,342         9.0
# 2    7                assessed      NaN         NaN         NaN
# 3    7               completed      NaN         NaN         NaN
# 4    7                 created      NaN         NaN         NaN
#
#                 programname       case_type category     benefit_type  \
# 0                       NaN             NaN      NaN              NaN
# 1  Earned Income Tax Credit  cash_household    taxes  ScreenerBenefit
# 2                       NaN             NaN      NaN              NaN
# 3                       NaN             NaN      NaN              NaN
# 4                       NaN             NaN      NaN              NaN
#
#             systemdate     ...      num_adults num_children num_hhmem  \
# 0                  NaN     ...             2.0          1.0       3.0
# 1  2017-02-07 16:32:53     ...             2.0          NaN       2.0
# 2                  NaN     ...             2.0          NaN       2.0
# 3                  NaN     ...             2.0          NaN       2.0
# 4                  NaN     ...             2.0          NaN       2.0
#
#    archived state  zip_code       intake_type     referral_type  \
# 0       NaN   NaN   11368.0            unsent               NaN
# 1       NaN    NY   10029.0  provider-created  intake_screening
# 2       NaN    NY   10029.0  provider-created  intake_screening
# 3       NaN    NY   10029.0  provider-created  intake_screening
# 4       NaN    NY   10029.0  provider-created  intake_screening
#
#   household_member_id  system_date
# 0                   3   2015-04-17
# 1                  10   2015-04-20
# 2                  10   2015-04-20
# 3                  10   2015-04-20
# 4                  10   2015-04-20
#
# [5 rows x 32 columns]

# %%
combined.to_csv("SingleStop_Combined.csv")
